# %%
import pandas as pd
import requests
from IPython.display import display, HTML, YouTubeVideo

# %%
plourl = "https://tastedive.com/api/similar"
with open("env_variables") as f:
    api_key = f.readlines()
    api_key = api_key[3]
    api_key = api_key[:-1]
data = {'q':'Up', 'type':'movies', 'info': [1], 'limit': [10], 'k': api_key}
resp = requests.get(url, data)
rec = resp.json()
for i in range(0,3):
    display(rec['Similar']['Results'][i]['Name'])
    display(YouTubeVideo(rec['Similar']['Results'][i]['yID'], width=400, height=300))
# Out:
# 'Ratatouille'
# 'Monsters, Inc.'
# 'Toy Story 3'
